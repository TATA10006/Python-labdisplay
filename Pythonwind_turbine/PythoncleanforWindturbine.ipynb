# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
# Issues arise because of the encoding, using latin1 because of the 0x1f in the error showing

Windturbine=pd.read_csv('./windturbine20220114.csv',engine='python',encoding='latin1')

# Make a copy of original csv
Windturbinecopy=Windturbine.copy()

# %%
Windturbine
# Out:
#        case_id    faa_ors           faa_asn  usgs_pr_id   eia_id t_state  \
# 0      3072661        NaN               NaN      5149.0  52161.0      CA
# 1      3072695        NaN               NaN      5143.0  52161.0      CA
# 2      3072704        NaN               NaN      5146.0  52161.0      CA
# 3      3063272  19-028134  2014-WTE-4084-OE         NaN      NaN      IA
# 4      3053390  19-028015  2015-WTE-6386-OE         NaN      NaN      IA
# ...        ...        ...               ...         ...      ...     ...
# 70803  3053232  36-120351  2015-WTE-5788-OE         NaN      NaN      NY
# 70804  3101958  48-171972  2020-WTW-2021-OE         NaN      NaN      TX
# 70805  3040944  48-024978   2011-WTW-352-OE     41364.0      NaN      TX
# 70806  3055918  08-072237  2015-WTW-9995-OE         NaN      NaN      CO
# 70807  3055917  08-072245  2015-WTW-9994-OE         NaN      NaN      CO
#
#              t_county  t_fips                   p_name  p_year  ...     t_rsa  \
# ...

# %%
# Count all null rows from the table
Windturbine.isnull().sum()
# Out:
# case_id              0
# faa_ors           5792
# faa_asn           5122
# usgs_pr_id       32545
# eia_id            5793
# t_state              0
# t_county             0
# t_fips               0
# p_name               0
# p_year             613
# p_tnum               0
# p_cap             4482
# t_manu            5640
# t_model           5777
# t_cap             5480
# t_hh              6180
# t_rd              5934
# t_rsa             5934
# t_ttlh            6180
# retrofit             0
# retrofit_year    64822
# t_conf_atr           0
# t_conf_loc           0
# t_img_date        8316
# t_img_srce           0
# xlong                0
# ylat                 0
# dtype: int64

# %%
Windturbine.describe()
# Out:
#             case_id    usgs_pr_id        eia_id        t_fips        p_year  \
# count  7.080800e+04  38263.000000  65015.000000  70808.000000  70195.000000
# mean   3.058490e+06  27523.587225  57877.751642  32244.494097   2011.650659
# std    3.242377e+04  13564.446593   5984.516487  15498.246596      7.879099
# min    3.000001e+06      1.000000     90.000000   2013.000000   1981.000000
# 25%    3.032230e+06  18625.500000  56763.000000  19081.000000   2008.000000
# 50%    3.050978e+06  28598.000000  57752.000000  35057.000000   2012.000000
# 75%    3.090448e+06  38719.500000  60338.000000  48141.000000   2018.000000
# max    3.118671e+06  49135.000000  65270.000000  72133.000000   2021.000000
#
#              p_tnum         p_cap         t_cap          t_hh          t_rd  \
# count  70808.000000  66326.000000  65328.000000  64628.000000  64874.000000
# mean     104.360552    170.176128   1963.534151     81.054571     95.663717
# ...

# %%
# Drop column faa_ors (Unique identifier for cross-reference to the Federal Aviation Administration (FAA) digital obstacle files).
# Drop column faa_asn (Unique identifier for cross-reference to the FAA obstruction evaluation airport airspace analysis dataset).
# Drop the entire column usgs_pr_id (Unique identifier for cross-reference to the 2014 USGS turbine dataset)
# Keep eid_id, p_year,p_cap....t_ttlh
# Drop both t_img_date & t_img_srce
# Drop t_conf_atr & t_conf_loc

Windturbine.drop(['faa_ors','faa_asn','usgs_pr_id','t_img_date','t_img_srce','t_conf_atr','t_conf_loc'],axis=1,inplace=True)

# %%
Windturbine.describe()
# Out:
#        case_id   eia_id t_state        t_county  t_fips  \
# 0      3072661  52161.0      CA     Kern County    6029
# 1      3072695  52161.0      CA     Kern County    6029
# 2      3072704  52161.0      CA     Kern County    6029
# 3      3063272      NaN      IA    Story County   19169
# 4      3053390      NaN      IA    Boone County   19015
# ...        ...      ...     ...             ...     ...
# 70803  3053232      NaN      NY  Wyoming County   36121
# 70804  3101958      NaN      TX    Young County   48503
# 70805  3040944      NaN      TX    Young County   48503
# 70806  3055918      NaN      CO     Yuma County    8125
# 70807  3055917      NaN      CO     Yuma County    8125
#
#                         p_name  p_year  p_tnum  p_cap  t_manu     t_model  \
# 0                     251 Wind  1987.0     194  18.43  Vestas         NaN
# 1                     251 Wind  1987.0     194  18.43  Vestas         NaN
# ...

# %% [markdown]
# Based on data distribution, we have applied
# median values to p_cap, t_cap, t_hh, t_rd and t_ttlh
# mean value to t_rsa

# %%
givevalues = {"p_cap": 158, "t_cap": 2000, "t_hh": 80, "t_rd": 100,"t_rsa": 7618.5,"t_ttlh": 130.1}

Windturbine.fillna(value=givevalues,inplace=True)

# %%
# Check if there is any duplicate values in case_id
Windturbine['case_id'].is_unique
# Out:
# True

# %%
Windturbine.to_csv (r'.\Cleaned_Windturbine.csv', index = False, header=True)
